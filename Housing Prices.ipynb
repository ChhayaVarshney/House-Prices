# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mtp
import missingno as msno

# %%
train=pd.read_csv("C:/Users/chhay/Desktop/Projects/Housing Prices/train.csv")
test=pd.read_csv("C:/Users/chhay/Desktop/Projects/Housing Prices/test.csv")
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
sns.heatmap(train.isnull())
# Out:
# <Axes: >

# %%
train_num = train.select_dtypes(include = ['float64', 'int64'])
train_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
for i in train_num.columns:
    sns.histplot(train_num[i])
    mtp.show()

# %% [markdown]
# Missing Values

# %%
train["LotFrontage"]=train["LotFrontage"].fillna(train["LotFrontage"].mean())

# %%
train.drop(["Alley"],axis=1,inplace=True)
train.drop(["MiscFeature"],axis=1,inplace=True)

# %%
train.drop(["Fence"],axis=1,inplace=True)
train.drop(["PoolQC"],axis=1,inplace=True)

# %%
train["FireplaceQu"]=train["FireplaceQu"].fillna(train["FireplaceQu"].mode()[0])
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])

# %%
train.dropna(subset=["MasVnrType"],inplace = True)
train.dropna(subset=["MasVnrArea"],inplace = True)
train.dropna(subset=["Electrical"],inplace = True)

# %%
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])

# %%
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])

# %%
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])
train["GarageYrBlt"]=train["GarageYrBlt"].fillna(train["GarageYrBlt"].mean())
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])

# %%
sns.heatmap(train.isnull())
# Out:
# <Axes: >

# %%
test.drop(["Alley"],axis=1,inplace=True)
test.drop(["MiscFeature"],axis=1,inplace=True)
test.drop(["Fence"],axis=1,inplace=True)
test.drop(["PoolQC"],axis=1,inplace=True)

# %%
test.shape
# Out:
# (1459, 76)

# %% [markdown]
# Fitting the model on data

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.concat([train,test],axis=0)
df.shape
# Out:
# (2910, 77)

# %%
train_cat = train.select_dtypes(include = ["object"])

# %%
columns=train_cat.columns.values.tolist()

# %%
def category_dummies(multcolumns):
    train_final=df
    i=0
    for fields in multcolumns:
        print(fields)
        df1=pd.get_dummies(df[fields],drop_first=True)
        df.drop([fields],axis=1,inplace=True)
        if i==0:
            train_final=df1.copy()
        else:
            train_final=pd.concat([train_final,df1],axis=1)
        i=i+1
    train_final=pd.concat([df,train_final],axis=1)
    return train_final

# %%
train_final=category_dummies(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition

# %%
train_final.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  ConLI  ConLw  New  Oth  WD  \
# 0          2003       196.0       706.0  ...      0      0    0    0   1
# 1          1976         0.0       978.0  ...      0      0    0    0   1
# 2          2002       162.0       486.0  ...      0      0    0    0   1
# 3          1970         0.0       216.0  ...      0      0    0    0   1
# 4          2000       350.0       655.0  ...      0      0    0    0   1
#
#    AdjLand  Alloca  Family  Normal  Partial
# ...

# %%
train_final=train_final.loc[:,~train_final.columns.duplicated()]

# %%
train_final.shape
# Out:
# (2910, 178)

# %%
train_df=train_final.iloc[:1451:]
test_df=train_final.iloc[1451::]

# %%
train_df.shape
# Out:
# (1451, 178)

# %%
x = train_df.drop("SalePrice",axis=1)
y = train_df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
#creating machine learning Logistic Regression model
from sklearn.linear_model import LinearRegression
lir = LinearRegression()
lir.fit(x_train,y_train)


pred = lir.predict(x_test)
R=r2_score(pred,y_test)
print(R)
# Out:
# 0.7363892140349022

# %%
rf = RandomForestClassifier(random_state = 1)
cv = cross_val_score(rf,x,y,cv=5)
print(cv)
print(cv.mean())
# Out:
# C:\Users\chhay\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [0.02061856 0.0137931  0.02758621 0.01724138 0.01724138]
# 0.01929612513330963
